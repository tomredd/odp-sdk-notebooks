# %%
import pandas as pd
import pydeck as pdk
from ODPworkspace_demotools import mapOQS, pydeck_plot
import matplotlib.pyplot as plt
from shapely.geometry import shape, MultiPolygon, Polygon
from shapely import wkt
from time import time
import geopandas as gpd
import os
from rasterio.io import MemoryFile
from IPython.display import display
from ipywidgets import widgets
from IPython.display import clear_output
import base64
import io
import warnings

# %%
from odp.client import OdpClient
from odp.dto import Metadata
from odp.dto.catalog import DatasetDto, DatasetSpec
from odp.dto.common.contact_info import ContactInfo

# %%
client = OdpClient()

# %%
dataset = client.catalog.get(("8131a076-af24-483b-b9a1-20a37433ef46")) ## UUID of ProtectedSeas dataset from the catalog
dataset.metadata.display_name
# Out:
# 'ProtectedSeas MPA Dataset'

# %% [markdown]
# ### List the Table Schema of ProtectedSeas Database

# %%
PSmetadata = client.tabular.get_schema(dataset)

# %%
table_schema = PSmetadata.table_schema

schema_data = []
for column, details in table_schema.items():
    schema_data.append({
        "Column Name": column,
        "Type": details.get('type', 'Unknown'),
        "Nullable": details.get('nullable', False),
        "Metadata": details.get('metadata', {})
    })

df = pd.DataFrame(schema_data)
df
# Out:
#                                      Column Name      Type  Nullable Metadata
# 0                           anchoring_prohibited      long      True       {}
# 1       removal_of_historic_artifacts_prohibited      long      True       {}
# 2                                 latest_updates    string      True       {}
# 3                             managing_authority    string      True       {}
# 4                                    hook_n_line      long      True       {}
# 5                                   bottom_trawl      long      True       {}
# 6                                           nets      long      True       {}
# 7                                        site_id    string      True       {}
# 8                      recreational_restrictions      long      True       {}
# 9                                 regulation_url    string      True       {}
# 10                                           url    string      True       {}
# 11                                   gillnetting      long      True       {}
# 12                              speed_restricted      long      True       {}
# 13  industrial_or_mineral_exploration_prohibited      long      True       {}
# 14                                  traps_n_pots      long      True       {}
# 15                                      year_est    double      True       {}
# 16                                     site_name    string      True       {}
# 17                            species_of_concern    string      True       {}
# 18                                     gov_level    string      True       {}
# 19                                      trolling      long      True       {}
# 20                                       wdpa_id    string      True       {}
# 21               overflight_or_drones_prohibited      long      True       {}
# 22                       construction_prohibited      long      True       {}
# 23                          discharge_prohibited      long      True       {}
# 24                           other_helpful_links    string      True       {}
# 25                       commercial_restrictions      long      True       {}
# 26                                     misc_gear      long      True       {}
# 27                              geometry_reduced  geometry      True       {}
# 28                            landing_prohibited      long      True       {}
# 29          removal_of_marine_life_is_prohibited      long      True       {}
# 30                               regulation_name    string      True       {}
# 31                              entry_prohibited      long      True       {}
# 32                                  inshore_only    double      True       {}
# 33                                effective_from    string      True       {}
# 34                                   designation    string      True       {}
# 35                                   last_update    string      True       {}
# 36                                       allowed    string      True       {}
# 37                           dragging_prohibited      long      True       {}
# 38                              protection_focus    string      True       {}
# 39                                       s57_cat    double      True       {}
# 40                           drilling_prohibited      long      True       {}
# 41                           dredging_prohibited      long      True       {}
# 42                                      geometry  geometry      True       {}
# 43                                      iucn_cat    string      True       {}
# 44                                        season    string      True       {}
# 45                               boundary_source    string      True       {}
# 46                                       purpose    string      True       {}
# 47                                    complexity      long      True       {}
# 48                                    longlining      long      True       {}
# 49                               coastline_match    double      True       {}
# 50                                        tribal      long      True       {}
# 51                                 spear_fishing      long      True       {}
# 52                                       country    string      True       {}
# 53                           stopping_prohibited      long      True       {}
# 54                                  restrictions    string      True       {}
# 55                                   definitions    string      True       {}
# 56                             diving_prohibited      long      True       {}
# 57                                         state    string      True       {}
# 58                                       ogc_fid      long      True       {}
# 59                                  effective_to    string      True       {}

# %% [markdown]
# ### Filter by Country

# %%
filter_query = {
  "#EQUALS": [
    "$country",
    "Denmark"
  ]
}

# %%
# MPSdata = client.tabular.select_as_dataframe(dataset) # without filter
PSdata = client.tabular.select_as_dataframe(dataset, filter_query=filter_query) # with filter
PSdata
# Out:
#                                         regulation_url  \
# 0    Fisheries Act|https://www.retsinformation.dk/F...
# 1    Act on Fishing and Hunting|http://extwprlegs1....
# 2    Act on Fishing and Hunting|http://extwprlegs1....
# 3    Fisheries Act|https://www.retsinformation.dk/F...
# 4    Council Directive 92/43/EEC|https://eur-lex.eu...
# ..                                                 ...
# 224  Council Directive 92/43/EEC|https://eur-lex.eu...
# 225  Council Directive 92/43/EEC|https://eur-lex.eu...
# 226  Regulations Text|https://www.retsinformation.d...
# 227  HELCOM Recommendation|https://www.helcom.fi/Re...
# 228  Council Directive 92/43/EEC|https://eur-lex.eu...
#
#                                        boundary_source  inshore_only  \
# 0    Flanders Marine Institute (2019). Maritime Bou...           0.0
# 1    Flanders Marine Institute (2019). Maritime Bou...           0.0
# 2    Flanders Marine Institute (2019). Maritime Bou...           0.0
# 3                                       Marine regions           0.0
# 4                                           Natura2000           0.0
# ..                                                 ...           ...
# 224                                             HELCOM           0.0
# 225                                             HELCOM           0.0
# 226                                             HELCOM           0.0
# 227                                             HELCOM           0.0
# 228                                         Natura2000           0.0
#
#     definitions  anchoring_prohibited  construction_prohibited  hook_n_line  \
# 0          None                     3                        3            3
# 1          None                     3                        3            3
# 2          None                     3                        3            3
# 3          None                     3                        3            3
# 4          None                     3                        3            3
# ..          ...                   ...                      ...          ...
# 224        None                     3                        2            3
# 225        None                     3                        2            2
# 226        None                     3                        3            3
# 227        None                     3                        2            3
# 228        None                     3                        3            3
#
#      dredging_prohibited  trolling  tribal  ...  \
# 0                      3         3       1  ...
# 1                      3         3       1  ...
# 2                      3         3       1  ...
# 3                      3         3       1  ...
# 4                      3         3       1  ...
# ..                   ...       ...     ...  ...
# 224                    2         3       1  ...
# 225                    2         3       1  ...
# 226                    3         3       1  ...
# 227                    2         3       1  ...
# 228                    3         3       1  ...
#
#                                              site_name coastline_match  \
# 0                                Denmark EEZ (0-200NM)             1.0
# 1                            Greenland Territorial Sea             1.0
# 2                                        Greenland EEZ             1.0
# 3                              Denmark Territorial Sea             1.0
# 4    Vadehavet med Ribe Å, Tved Å og Varde Å vest f...             1.0
# ..                                                 ...             ...
# 224                                      Hvideodde Rev             0.0
# 225                                      Ebbeløkke Rev             0.0
# 226                     Hesselø med omliggende stenrev             0.0
# 227                      Kims Top og den Kinesiske Mur             0.0
# 228                                 Thyborøn Stenvolde             0.0
#
#                                         latest_updates  \
# 0    For updates on fisheries regulalations in mari...
# 1                                                 None
# 2                                                 None
# 3    For updates on fisheries regulalations in mari...
# 4    For updates on fisheries regulalations in mari...
# ..                                                 ...
# 224  For updates on fisheries regulalations in mari...
# 225  For updates on fisheries regulalations in mari...
# 226  For updates on fisheries regulalations in mari...
# 227  For updates on fisheries regulalations in mari...
# 228  For updates on fisheries regulalations in mari...
#
#     industrial_or_mineral_exploration_prohibited      season  \
# 0                                              3  Year-round
# 1                                              3  Year-round
# 2                                              3  Year-round
# 3                                              3  Year-round
# 4                                              3  Year-round
# ..                                           ...         ...
# 224                                            2  Year-round
# 225                                            2  Year-round
# 226                                            3  Year-round
# 227                                            2  Year-round
# 228                                            3  Year-round
#
#                                       geometry_reduced  state  longlining  \
# 0    {'type': 'MultiPolygon', 'coordinates': [[[[16...   None           2
# 1    {'type': 'MultiPolygon', 'coordinates': [[[[-3...   None           3
# 2    {'type': 'MultiPolygon', 'coordinates': [[[[-1...   None           3
# 3    {'type': 'MultiPolygon', 'coordinates': [[[[15...   None           2
# 4    {'type': 'MultiPolygon', 'coordinates': [[[[8....   None           3
# ..                                                 ...    ...         ...
# 224  {'type': 'MultiPolygon', 'coordinates': [[[[14...   None           3
# 225  {'type': 'MultiPolygon', 'coordinates': [[[[11...   None           1
# 226  {'type': 'MultiPolygon', 'coordinates': [[[[11...   None           3
# 227  {'type': 'MultiPolygon', 'coordinates': [[[[11...   None           3
# 228  {'type': 'MultiPolygon', 'coordinates': [[[[7....   None           3
#
#      entry_prohibited                                    regulation_name
# 0                   3  Fisheries Act; Executive Order on Recreational...
# 1                   3  Act on Fishing and Hunting (No. 12 of 1999);  ...
# 2                   3  Act on Fishing and Hunting (No. 12 of 1999);  ...
# 3                   3  Fisheries Act; Executive Order on Recreational...
# 4                   3  Council Directive 92/43/EEC of 21 May 1992 on ...
# ..                ...                                                ...
# 224                 3  Council Directive 92/43/EEC of 21 May 1992 on ...
# 225                 3  Council Directive 92/43/EEC of 21 May 1992 on ...
# 226                 3  Decree on special fisheries regulation in mari...
# 227                 3  HELCOM Recommendation 35/1; Council Directive ...
# 228                 3  Council Directive 92/43/EEC of 21 May 1992 on ...
#
# [229 rows x 60 columns]

# %% [markdown]
# ### Export Data in Different Formats

# %%
def export_PSdata(PSdata):
    """
    Export the PSdata DataFrame to selected file formats with browser downloads in Jupyter.
    
    Parameters:
    -----------
    PSdata : pandas.DataFrame or geopandas.GeoDataFrame
        The dataframe to be exported
    
    Returns:
    --------
    None
        Generates downloadable files for selected formats
    """
    # Available export formats
    export_formats = {
        'Shapefile': '.shp',
        'GeoJSON': '.geojson',
        'GPKG': '.gpkg',
        'CSV': '.csv',
        'SVG': '.svg'
    }
    
    # Create widgets
    format_label = widgets.Label("Select Export Formats:")
    format_checkboxes = {
        format_name: widgets.Checkbox(description=format_name, value=False) 
        for format_name in export_formats.keys()
    }
    
    # Download button and output
    download_button = widgets.Button(description="Generate Downloads")
    output = widgets.Output()
    
    # Arrange widgets
    format_box = widgets.VBox(list(format_checkboxes.values()))
    widget_layout = widgets.VBox([
        format_label, 
        format_box, 
        download_button, 
        output
    ])
    
    def create_download_link(data, filename):
        """
        Create a downloadable link for browser download.
        
        Parameters:
        -----------
        data : bytes
            File content to be downloaded
        filename : str
            Name of the file to be downloaded
        
        Returns:
        --------
        widgets.HTML
            A download link widget
        """
        b64 = base64.b64encode(data).decode()
        html = f'''
        <a download="{filename}" href="data:application/octet-stream;base64,{b64}" download>
            Download {filename}
        </a>
        '''
        return widgets.HTML(html)
    
    def on_download_click(b):
        with output:
            output.clear_output()
            
            # Determine selected formats
            selected_formats = [
                format_name for format_name, checkbox in format_checkboxes.items() 
                if checkbox.value
            ]
            
            if not selected_formats:
                print("❌ Error: No formats selected!")
                return
            
            # Download links to be displayed
            download_links = []
            
            # Export to selected formats
            try:
                for format_name in selected_formats:
                    # Prepare buffer for file content
                    buffer = io.BytesIO()
                    
                    # Export based on format
                    if format_name == 'Shapefile':
                        # Convert regular DataFrame to GeoDataFrame if needed
                        if not isinstance(PSdata, gpd.GeoDataFrame):
                            try:
                                # Attempt to convert to GeoDataFrame 
                                # Assumes you might have geometry column
                                gdf = gpd.GeoDataFrame(PSdata)
                            except Exception:
                                # Fallback: create a simple GeoDataFrame
                                gdf = gpd.GeoDataFrame(
                                    PSdata, 
                                    geometry=gpd.points_from_xy(
                                        PSdata.get('longitude', 0), 
                                        PSdata.get('latitude', 0)
                                    )
                                )
                        else:
                            gdf = PSdata
                        
                        # For Shapefile, we need to save multiple files
                        temp_dir = 'temp_shapefile'
                        os.makedirs(temp_dir, exist_ok=True)
                        shapefile_path = os.path.join(temp_dir, 'PSdata.shp')
                        gdf.to_file(shapefile_path)
                        
                        # Create a zip file of the shapefile components
                        import shutil
                        shutil.make_archive('PSdata_shapefile', 'zip', temp_dir)
                        
                        with open('PSdata_shapefile.zip', 'rb') as f:
                            buffer.write(f.read())
                        
                        # Clean up temporary files
                        shutil.rmtree(temp_dir)
                        os.remove('PSdata_shapefile.zip')
                        
                        download_link = create_download_link(
                            buffer.getvalue(), 
                            f'PSdata{export_formats[format_name]}.zip'
                        )
                    
                    elif format_name in ['GeoJSON', 'GPKG']:
                        # Convert regular DataFrame to GeoDataFrame if needed
                        if not isinstance(PSdata, gpd.GeoDataFrame):
                            try:
                                # Attempt to convert to GeoDataFrame 
                                # Assumes you might have geometry column
                                gdf = gpd.GeoDataFrame(PSdata)
                            except Exception:
                                # Fallback: create a simple GeoDataFrame
                                gdf = gpd.GeoDataFrame(
                                    PSdata, 
                                    geometry=gpd.points_from_xy(
                                        PSdata.get('longitude', 0), 
                                        PSdata.get('latitude', 0)
                                    )
                                )
                        else:
                            gdf = PSdata
                        
                        # Export to specific format
                        driver = 'GeoJSON' if format_name == 'GeoJSON' else 'GPKG'
                        gdf.to_file(buffer, driver=driver)
                        download_link = create_download_link(
                            buffer.getvalue(), 
                            f'PSdata{export_formats[format_name]}'
                        )
                    
                    elif format_name == 'CSV':
                        PSdata.to_csv(buffer, index=False)
                        download_link = create_download_link(
                            buffer.getvalue(), 
                            f'PSdata{export_formats[format_name]}'
                        )
                    
                    elif format_name == 'SVG':
                        import matplotlib.pyplot as plt
                        fig, ax = plt.subplots(figsize=(10, 10))
                        PSdata.plot(ax=ax)
                        plt.savefig(buffer, format='svg')
                        plt.close()
                        download_link = create_download_link(
                            buffer.getvalue(), 
                            f'PSdata{export_formats[format_name]}'
                        )
                    
                    download_links.append(download_link)
                
                # Display download links
                if download_links:
                    print("✅ Downloads generated!")
                    for link in download_links:
                        display(link)
                else:
                    print("❌ No valid downloads could be created.")
            
            except Exception as e:
                print(f"❌ Export Error: {e}")
    
    # Attach click event
    download_button.on_click(on_download_click)
    
    # Display widgets
    display(widget_layout)

# %%
export_PSdata(PSdata)
# Out:
# VBox(children=(Label(value='Select Export Formats:'), VBox(children=(Checkbox(value=False, description='Shapef…
